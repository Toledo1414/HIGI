# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
def Kepler(x0, y0, z0, vx0, vy0, vz0, t0=0, dt=0.001 ,nsteps=100):
    rp = math.sqrt( x0**2 + y0**2 + z0**2)
    G = 4*(math.pi**2)
    x = [x0] 
    y = [y0]
    z = [z0]
    vx = [vx0]
    vy = [vy0]
    vz = [vz0]
    t = [t0]
    for i in range(1, nsteps):
        Vxi = vx0 - ( (G) / rp**3 )*x0 *dt 
        xi = x0 + Vxi*dt
        Vyi = vy0 - ( (G) / rp**3 )*y0 *dt 
        yi = y0 + Vyi*dt
        Vzi = vz0 - ( (G) / rp**3 )*z0 *dt 
        zi = z0 + Vzi*dt
        x.append(xi)
        y.append(yi)
        z.append(zi)
        t.append(t0 + dt*i)
        x0 = xi
        y0 = yi
        z0 = zi
        vx0 = Vxi 
        vy0 = Vyi
        vz0 = Vzi
        
    return x, y, z, vx, vy, vz, t

# %%
"""Mercurio"""
x,y,z,vx,vy,vz,t= Kepler(0.0508011, -0.4011642, -0.2195576, 0.02231875,0.00485553,0.00027924)
plt.plot(t,x)
plt.plot(t,y)
plt.plot(t,z)

# %%
x,y,z,vx,vy,vz,t= Kepler(0.0508011, -0.4011642, -0.2195576, 0.02231875,0.00485553,0.00027924)
plt.plot(t,vx)
plt.plot(t,vy)
plt.plot(t,vz)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 2>()
#       1 x,y,z,vx,vy,vz,t= Kepler(0.0508011, -0.4011642, -0.2195576, 0.02231875,0.00485553,0.00027924)
# ----> 2 plt.plot(t,vx)
#       3 plt.plot(t,vy)
#       4 plt.plot(t,vz)
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2769, in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
# ...

# %%
"""Venus"""
x,y,z,vx,vy,vz,t= Kepler(0.0655112, -0.6589741, -0.3006194, 0.02000833,0.00205477,0.00034178)
plt.plot(t,x)
plt.plot(t,y)
plt.plot(t,z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 6>()
#       4 plt.plot(t,y)
#       5 plt.plot(t,z)
# ----> 6 plt.plot(t,rp)
#
# NameError: name 'rp' is not defined

# %%
"""Tierra"""
x,y,z,vx,vy,vz,t= Kepler(-0.6349052, 0.6910548,0.29959, -0.01343443,0.01023223,)
plt.plot(t,x)
plt.plot(t,y)
plt.plot(t,z)
