# %%
import numpy as np
import matplotlib.pyplot as plt
import os 
import math as math

# %%
data= np.loadtxt("IRCF.txt").T
x= data[0]
y=data[1]
yerror=[3]

plt.errorbar(x,y,yerror)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
c=2.998*10**10
h=6.626*10**-32
k=1.380*10**-21

def Intrad(T,v):
(h*(v**3)/c**2)*1/(np.exp(h*v/kT)-1)

return Intrad
